# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

client = OpenAI(
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    base_url=os.getenv("AZURE_OPENAI_WEBSEARCH_ENDPOINT"),
)

response = client.responses.create(   
  model="gpt-4o-mini",
  tools=[{"type": "web_search_preview"}], 
  input="오늘 용인 날씨를 알려줘"
)

print(response.output_text)
# Out:
# 오늘 용인의 날씨는 다음과 같습니다:
#
# - **현재 기온**: 약 7도
# - **최고 기온**: 10도
# - **최저 기온**: -1도
# - **날씨**: 대체로 흐림, 비가 소량 내릴 가능성 있음
# - **습도**: 약 92%
# - **바람**: 남서쪽에서 시속 11km로 불고 있음
#
# **비예보**: 오늘 오전 중에는 비가 올 가능성이 있으며, 오후에는 그치겠습니다.
#
# 더 자세한 정보는 [기상청](http://www.kma.go.kr/weather/forecast/timeseries.jsp?searchType=SETINFO&setinfoCode=4146136000)에서 확인하실 수 있습니다.

# %%
import os
from openai import OpenAI


response = client.responses.create(   
  model="gpt-4o-mini",
  tools= [
        {
            "type": "web_search_preview",
            "user_location": {
                "type": "approximate",
                "country": "KR"
            }
        }
    ],
    input="날씨 알려줘"
)

print(response.output_text)
# Out:
# 현재 서울의 날씨는 맑고 기온은 약 10도이며, 최저 기온은 5도, 최고 기온은 15도로 예상됩니다. 현재 습도는 60%입니다. 오늘 강수 확률은 0%로 비 소식은 없습니다.
#
# 보다 자세한 정보는 기상청 날씨누리 사이트에서 확인할 수 있습니다: [기상청 날씨누리](https://www.weather.go.kr/w/index.do).
